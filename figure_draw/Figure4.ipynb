# %%
#Figure4 对应 FSW ，SFSW， OPLR-TP ， MS-BU方法在不同的分段误差条件下的平均表示误差

# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Oct  7 14:08:06 2020

@author: Administrator
"""
import numpy as np
import matplotlib.pyplot as plt
NARE_FSW=[1.00 ,1.99 ,3.49 ,4.37 ,5.29 ]
NARE_SFSW=[0.78 ,1.74 ,2.66 ,3.38 ,4.21 ]
NARE_OPLR=[0.91 ,1.43 ,1.66 ,2.00 ,2.14 ]
NARE_MS_BU=[0.82 ,1.12,1.34 ,1.54 ,1.70 ]

# =============================================================================
# SNS_FSW=[1,0.56,0.34,0.23,0.16]
# SNS_SFSW=[1.1,0.67,0.4,0.28,0.19]
# SNS_OPLR=[1.14,0.91,0.73,0.63,0.55]
# SNS_MS_BU=[1.3,0.93,0.73,0.64,0.57]
# 
# 
# RT_FSW=[1,0.886,0.830,0.769,0.748]
# RT_SFSW=[4.88,2.609,1.606,1.179,0.996]
# RT_OPLR=[4.65,3.598,2.839,2.428,2.171]
# RT_MS_BU=[6.71,4.072,3.343,2.438,2.159]
# =============================================================================


MEPP = ['10%','20%','30%','40%','50%']
# =============================================================================
# plt.figure(figsize=(12,6))
# #plt.scatter(MEPP,mean_squar_FSW_error_SAP,color='orange',label='FSW')
# plt.plot(MEPP,RT_FSW,'--^',label='FSW' )
# 
# #plt.scatter(MEPP,mean_squar_SFSW_error_SAP,color='green',label='SFSW')
# plt.plot(MEPP,RT_SFSW,'--v',label='SFSW')
# 
# #plt.scatter(MEPP,mean_squar_OPLR_error_SAP,color='red',label='OPLR_TP')
# plt.plot(MEPP,RT_OPLR,'--h',label='OPLR-TP' )
# 
# #plt.scatter(MEPP,mean_squar_MS_BU_error_SAP,color='pink',label='MS-BU')
# plt.plot(MEPP,RT_MS_BU,'--*',label='MS-BU' )
# 
# plt.title("Normalized Running Time Experiment")
# plt.legend()
# plt.show()
# =============================================================================

plt.figure(figsize=(12,6))
#plt.scatter(MEPP,mean_squar_FSW_error_SAP,color='orange',label='FSW')
plt.plot(MEPP,NARE_FSW,'-x',label='FSW' )

#plt.scatter(MEPP,mean_squar_SFSW_error_SAP,color='green',label='SFSW')
plt.plot(MEPP,NARE_SFSW,':v',label='SFSW')

#plt.scatter(MEPP,mean_squar_OPLR_error_SAP,color='red',label='OPLR_TP')
plt.plot(MEPP,NARE_OPLR,'-.h',label='OPLR-TP' )

#plt.scatter(MEPP,mean_squar_MS_BU_error_SAP,color='pink',label='MS-BU')
plt.plot(MEPP,NARE_MS_BU,'--*',label='MS-BU' )

#plt.title("NARE plot Experiment")
font2 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 15,
}
plt.ylabel("NARE",font2)
plt.grid(axis="y")
plt.tick_params(labelsize=13)
plt.legend(prop={'size':16})

plt.show()

# =============================================================================
# plt.figure(figsize=(12,6))
# #plt.scatter(MEPP,mean_squar_FSW_error_SAP,color='orange',label='FSW')
# plt.plot(MEPP,SNS_FSW,'--^',label='FSW' )
# 
# #plt.scatter(MEPP,mean_squar_SFSW_error_SAP,color='green',label='SFSW')
# plt.plot(MEPP,SNS_SFSW,'--v',label='SFSW')
# 
# #plt.scatter(MEPP,mean_squar_OPLR_error_SAP,color='red',label='OPLR_TP')
# plt.plot(MEPP,SNS_OPLR,'--h',label='OPLR-TP' )
# 
# #plt.scatter(MEPP,mean_squar_MS_BU_error_SAP,color='pink',label='MS-BU')
# plt.plot(MEPP,SNS_MS_BU,'--*',label='MS-BU' )
# 
# plt.title("NSN plot Experiment")
# plt.grid(axis="y")
# plt.legend(prop={'size':16})
# plt.show()
# =============================================================================
